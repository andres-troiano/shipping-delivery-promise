# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook is reserved for dataset inspection, exploratory analysis, and sanity checks in later stages of the prototype.
#
# No analysis is implemented in Stage 1.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/nyc_taxi_train.csv")

# %%
print("Columns:")
print(df.columns)

print("\nTrip duration summary:")
print(df.trip_duration.describe())

print("\nCoordinate ranges:")
print(df[['pickup_latitude','pickup_longitude','dropoff_latitude','dropoff_longitude']].describe())

print("\nSample rows:")
print(df.head())
# Out:
# Columns:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration'],
#       dtype='str')
#
# Trip duration summary:
# count    1.458644e+06
# mean     9.594923e+02
# std      5.237432e+03
# min      1.000000e+00
# 25%      3.970000e+02
# 50%      6.620000e+02
# 75%      1.075000e+03
# max      3.526282e+06
# Name: trip_duration, dtype: float64
#
# Coordinate ranges:
#        pickup_latitude  pickup_longitude  dropoff_latitude  dropoff_longitude
# count     1.458644e+06      1.458644e+06      1.458644e+06       1.458644e+06
# mean      4.075092e+01     -7.397349e+01      4.075180e+01      -7.397342e+01
# std       3.288119e-02      7.090186e-02      3.589056e-02       7.064327e-02
# min       3.435970e+01     -1.219333e+02      3.218114e+01      -1.219333e+02
# ...

# %%
train_df = pd.read_csv("../data/processed/train.csv")

# %%
train_df.columns.tolist()
# Out:
# ['pickup_datetime',
#  'lead_time_minutes',
#  'prep_time_minutes',
#  'pickup_delay_minutes',
#  'delivery_duration_minutes',
#  'seller_category',
#  'seller_reliability',
#  'seller_avg_prep_minutes',
#  'order_size',
#  'priority_flag',
#  'courier_load',
#  'is_high_complexity_order',
#  'hour_of_day',
#  'day_of_week',
#  'month',
#  'is_weekend',
#  'is_peak_hour',
#  'trip_distance_km',
#  'pickup_latitude',
#  'pickup_longitude',
#  'dropoff_latitude',
#  'dropoff_longitude',
#  'split']

# %%
train_df.dtypes
# Out:
# pickup_datetime                  str
# lead_time_minutes            float64
# prep_time_minutes            float64
# pickup_delay_minutes         float64
# delivery_duration_minutes    float64
# seller_category                  str
# seller_reliability           float64
# seller_avg_prep_minutes        int64
# order_size                     int64
# priority_flag                  int64
# courier_load                 float64
# is_high_complexity_order       int64
# hour_of_day                    int64
# day_of_week                    int64
# month                          int64
# is_weekend                     int64
# is_peak_hour                   int64
# trip_distance_km             float64
# pickup_latitude              float64
# pickup_longitude             float64
# dropoff_latitude             float64
# dropoff_longitude            float64
# split                            str
# dtype: object

# %%
import numpy as np

check = np.allclose(
    train_df["lead_time_minutes"],
    train_df["prep_time_minutes"]
    + train_df["pickup_delay_minutes"]
    + train_df["delivery_duration_minutes"]
)

print(check)
# Out:
# True
